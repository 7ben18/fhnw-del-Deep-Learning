# %% [markdown]
# # Bibliothek importieren

# %%
import torch
import numpy as np

# %%
x = torch.randn(3, requires_grad=True)
display(x)

y = x + 2 
display(y)
# Out:
# tensor([-0.1209, -0.3335, -0.9374], requires_grad=True)
# tensor([1.8791, 1.6665, 1.0626], grad_fn=<AddBackward0>)

# %% [markdown]
# Was passiert?
#
#
# ![image.png](attachment:image.png)
#
#
# Fuer was wir requires_grad brauchen?
#
# ![image.png](attachment:image-2.png)

# %%
z = y * y * 2
display(z)

z = z.mean()
display(z)

# calculate the gradients
z.backward()  # dz/dx
display(x.grad)
# Out:
# tensor([7.0623, 5.5541, 2.2582], grad_fn=<MulBackward0>)
# tensor(4.9582, grad_fn=<MeanBackward0>)
# tensor([ 8.2682, 13.3316,  4.2508])

# %% [markdown]
# Jacobimatrix
#
# ![image.png](attachment:image.png)

# %%
z = y * y * 2
display(z)

v = torch.tensor([0.1, 1.0, 0.001], dtype=torch.float32)

z.backward(v) # dz/dx
display(x.grad)
# Out:
# tensor([7.0623, 5.5541, 2.2582], grad_fn=<MulBackward0>)
# tensor([ 9.0199, 19.9974,  4.2551])

# %% [markdown]
# # Stop autograd from tracking history on Tensors

# %%
x = torch.randn(3, requires_grad=True)
display(x)

# set requires_grad=False to stop tracking the history
x.requires_grad_(False)
display(x)
# Out:
# tensor([-2.4217, -1.3284, -1.5120], requires_grad=True)
# tensor([-2.4217, -1.3284, -1.5120])

# %%
x = torch.randn(3, requires_grad=True)
display(x)

y = x.detach()
display(y)
# Out:
# tensor([1.0235, 0.5018, 2.1201], requires_grad=True)
# tensor([1.0235, 0.5018, 2.1201])

# %%
x = torch.randn(3, requires_grad=True)
display(x)

with torch.no_grad():
    y = x + 2
    display(y)
# Out:
# tensor([-0.1416, -1.4060,  1.8075], requires_grad=True)
# tensor([1.8584, 0.5940, 3.8075])

# %% [markdown]
# # Weights are summing!

# %%
weights = torch.ones(4, requires_grad=True)

for epoch in range(6):
    model_output = (weights * 3).sum()

    model_output.backward()

    print(weights.grad)
# Out:
# tensor([3., 3., 3., 3.])
# tensor([6., 6., 6., 6.])
# tensor([9., 9., 9., 9.])
# tensor([12., 12., 12., 12.])
# tensor([15., 15., 15., 15.])
# tensor([18., 18., 18., 18.])

# %% [markdown]
# # How to correct it

# %%
weights = torch.ones(4, requires_grad=True)

for epoch in range(6):
    model_output = (weights * 3).sum()

    model_output.backward()

    print(weights.grad)

    weights.grad.zero_()
# Out:
# tensor([3., 3., 3., 3.])
# tensor([3., 3., 3., 3.])
# tensor([3., 3., 3., 3.])
# tensor([3., 3., 3., 3.])
# tensor([3., 3., 3., 3.])
# tensor([3., 3., 3., 3.])

# %% [markdown]
# # Anwendung

# %%
weights = torch.ones(4, requires_grad=True)

optimizer = torch.optim.SGD(weights, lr=0.01)
optimizer.step()
optimizer.zero_grad()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 3
#       1 weights = torch.ones(4, requires_grad=True)
# ----> 3 optimizer = torch.optim.SGD(weights, lr=0.01)
#       4 optimizer.step()
#       5 optimizer.zero_grad()
#
# File c:\Users\Si Ben Tran\venv\del\lib\site-packages\torch\optim\sgd.py:109, in SGD.__init__(self, params, lr, momentum, dampening, weight_decay, nesterov, maximize, foreach, differentiable)
#     107 if nesterov and (momentum <= 0 or dampening != 0):
#     108     raise ValueError("Nesterov momentum requires a momentum and zero dampening")
# --> 109 super(SGD, self).__init__(params, defaults)
#
# File c:\Users\Si Ben Tran\venv\del\lib\site-packages\torch\optim\optimizer.py:52, in Optimizer.__init__(self, params, defaults)
#      49 self._hook_for_profile()
#      51 if isinstance(params, torch.Tensor):
# ---> 52     raise TypeError("params argument given to the optimizer should be "
#      53                     "an iterable of Tensors or dicts, but got " +
#      54                     torch.typename(params))
#      56 self.state = defaultdict(dict)
#      57 self.param_groups = []
#
# TypeError: params argument given to the optimizer should be an iterable of Tensors or dicts, but got torch.FloatTensor
